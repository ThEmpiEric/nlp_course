# %% [markdown]
# # Text Mining
#
# El siguiente notebook realiza una extracccion de las informes estenográficos de AMLO y la presidenta actual de Mexico Clausia Sheimbaum.
#
# Eric Lemus Avalos

# %%
# Librerias 
import os
import wget
import glob
import re 
import time 
import nltk 
import requests
from datetime import datetime

# Pulling data out HTML file
from bs4 import BeautifulSoup

# Manipulación de Data 
import polars as pl

# %%
workdir = os.getcwd()
workdir
# Out:
# 'C:\\Users\\ericl\\tareas_nlp'

# %% [markdown]
# ### Versiones estenograficas de AMLO

# %%
paginas_dir = os.path.join(workdir, "paginas")

if not os.path.exists(paginas_dir):
    os.makedirs(paginas_dir)

url_pagina_i = 'https://amlo.presidente.gob.mx/secciones/version-estenografica/page/'
num_pag = 153 # paginas validad con versiones estenograficas
for i in range(num_pag):
    wget.download(url= url_pagina_i + str(i+1), out = "./paginas/" + str(i+1) + ".txt")

# %% [markdown]
# Buscamos el patron de los urls de las versiones estenográficas para Andrés Manuel López Obrador.

# %%
paginas_path = r'./paginas/*'
pattern = r'href="(https://amlo\.presidente\.gob\.mx/\d{2}-\d{2}-\d{2}-version-estenografica-[^"]+)"'

# %%
# Lista para almacenar las URLs encontradas
urls_config = []

# Procesar los archivos en la carpeta
for file_pagina in glob.glob(paginas_path):
    # print(f"Procesando archivo: {file_pagina}")
    with open(file_pagina, 'r', encoding='utf-8') as f:
        content = f.read()     
        # Buscar todas las coincidencias en el contenido del archivo
        urls_encontradas = re.findall(pattern, content) 
        # Agregar las URLs encontradas a la lista
        urls_config.extend(urls_encontradas)

# %%
urls_config[:10]
# Out:
# ['https://amlo.presidente.gob.mx/30-09-24-version-estenografica-de-la-ultima-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/',
#  'https://amlo.presidente.gob.mx/30-09-24-version-estenografica-de-la-ultima-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/',
#  'https://amlo.presidente.gob.mx/29-09-24-version-estenografica-tren-maya-y-entrega-de-reconocimientos-a-ingenieros-constructores-desde-chetumal-quintana-roo/',
#  'https://amlo.presidente.gob.mx/29-09-24-version-estenografica-tren-maya-y-entrega-de-reconocimientos-a-ingenieros-constructores-desde-chetumal-quintana-roo/',
#  'https://amlo.presidente.gob.mx/28-09-24-version-estenografica-inauguracion-zona-de-riego-de-la-presa-santa-maria-desde-el-rosario-sinaloa/',
#  'https://amlo.presidente.gob.mx/28-09-24-version-estenografica-inauguracion-zona-de-riego-de-la-presa-santa-maria-desde-el-rosario-sinaloa/',
#  'https://amlo.presidente.gob.mx/27-09-24-version-estenografica-entrega-de-acueducto-y-distrito-de-riego-al-pueblo-yaqui-desde-guaymas-sonora/',
#  'https://amlo.presidente.gob.mx/27-09-24-version-estenografica-entrega-de-acueducto-y-distrito-de-riego-al-pueblo-yaqui-desde-guaymas-sonora/',
#  'https://amlo.presidente.gob.mx/27-09-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/',
#  'https://amlo.presidente.gob.mx/27-09-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/']

# %%
# Numero de versiones estenograficas encontradas
len(set(urls_config))
# Out:
# 1963

# %%
urls = list(set(urls_config))
urls[:5]
# Out:
# ['https://amlo.presidente.gob.mx/26-09-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/',
#  'https://amlo.presidente.gob.mx/13-12-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/',
#  'https://amlo.presidente.gob.mx/02-08-24-version-estenografica-inauguracion-del-puente-la-concordia-desde-chiapas/',
#  'https://amlo.presidente.gob.mx/13-12-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/',
#  'https://amlo.presidente.gob.mx/06-10-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-huajuapan-de-leon-oaxaca/']

# %% [markdown]
# Guardamos los urls de las versiones estenogáficas

# %%
with open('conferencias_urls.txt', 'w', encoding='utf-8') as file:
    for url in urls:
        file.write(url + "\n")

# %% [markdown]
# Utilizamos ```requests```
#
# Parseamos del HTML para obtener el texto limpio.

# %%
import requests

#ejemplo de url
url = "https://amlo.presidente.gob.mx/21-07-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/"

response = requests.get(url)
if response.status_code == 200:
    # Parsear el contenido HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Buscar cintenido 
    contenido_relevante = soup.find("div", class_="entry-content")
    
    if contenido_relevante:
        texto = contenido_relevante.get_text(strip=True)
        # print(texto)
    else:
        print("No se encontró contenido relevante en la página.")

else:
    print(f"Error al acceder a la página: {response.status_code}")

# %%
texto[:1000] #mostramps los primeros 1000 caracteres.
# Out:
# '2020, Año de Leona Vicario, Benemérita Madre de la PatriaPRESIDENTE ANDRÉS MANUEL LÓPEZ OBRADOR:Buenos días.Vamos a tratar el día de hoy, como todos los martes, el tema de la salud, de cómo se va a avanzando en el combate a la pandemia. Nos van a informar, tanto el doctor Alcocer como el doctor Hugo López-Gatell.También va a informar Marcelo Ebrard sobre la situación de nuestros paisanos en el extranjero y los protocolos, el avance, la participación de México para la creación y distribución, obtención de la vacuna. Eso también es un tema importante.Tenemos que seguir enfrentando esta pandemia, que va a la baja; muy lentamente, pero a baja. No hemos tenido problemas mayores en cuanto a hospitalización, no ha habido saturación de hospitales, se está atendiendo diariamente esta demanda; donde se requiere, todos juntos, todos los integrantes del sector salud actúan para que haya camas, para que haya equipos, para que no falten los especialistas y vamos avanzando, saliendo adelante frente a'

# %% [markdown]
# #### Extracción del texto para cada versión estenografica

# %%
output_folder = "versiones_estenograficas_amlo"
os.makedirs(output_folder, exist_ok=True)

# %%
with open('conferencias_urls.txt', 'r', encoding='utf-8') as file:
    urls = [line.strip() for line in file]

fallidos = []

for url in urls:
    print(f"Procesando: {url}")
    try:
        response = requests.get(url)
        
        if response.status_code == 200:
            # Parsear el contenido HTML de la pagina
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Buscar el contenido inspeccionado
            contenido_relevante = soup.find("div", class_="entry-content")
            
            if contenido_relevante:
                texto = contenido_relevante.get_text(strip=True)
                nombre_archivo = url.split("/")[-2] 
                archivo_salida = os.path.join(output_folder, f"{nombre_archivo}.txt")
                
                with open(archivo_salida, 'w', encoding='utf-8') as output_file:
                    output_file.write(texto)
            else:
                # print(f"No se encontró contenido relevante en {url}")
                fallidos.append(url)
        else:
            # print(f"Error al acceder a {url}: {response.status_code}")
            fallidos.append(url)
    except Exception as e:
        print(f"Error procesando {url}: {e}")
        fallidos.append(url)

if fallidos:
    print(f"\nNúmero de conferencias que no se pudieron descargar: {len(fallidos)}")
    print("URLs de las conferencias fallidas:")
    for fallido in fallidos:
        print(fallido)
# Out:
# Procesando: https://amlo.presidente.gob.mx/22-08-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-05-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/12-10-20-version-estenografica-graduacion-15a-generacion-del-curso-de-formacion-del-servicio-de-proteccion-federal/
# Procesando: https://amlo.presidente.gob.mx/21-02-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-la-paz-baja-california-sur/
# Procesando: https://amlo.presidente.gob.mx/13-10-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-02-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/06-08-22-version-estenografica-evaluacion-general-de-universidades-para-el-bienestar-benito-juarez-desde-armeria-colima/
# Procesando: https://amlo.presidente.gob.mx/26-02-24-version-estenografica-inauguracion-del-rompeolas-del-puerto-de-salina-cruz-en-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/11-06-22-version-estenografica-modernizacion-del-puerto-de-salina-cruz-desde-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/10-01-21-version-estenografica-visita-al-recinto-portuario-de-manzanillo-colima/
# Procesando: https://amlo.presidente.gob.mx/25-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-01-23-version-estenografica-plan-de-apoyo-a-poblacion-afectada-por-huracan-agatha-en-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/16-06-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-02-20-version-estenografica-programa-de-mejoramiento-urbano-desde-solidaridad-quintana-roo/
# Procesando: https://amlo.presidente.gob.mx/01-08-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-06-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-en-cancun-quintana-roo/
# Procesando: https://amlo.presidente.gob.mx/28-11-22-version-estenografica-de-a-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/21-04-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-01-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-02-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-09-20-version-estenografica-inauguracion-primera-etapa-de-intervencion-del-parque-cuitlahuac-desde-iztapalapa-ciudad-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/02-06-23-version-estenografica-plan-de-salud-imss-bienestar-quintana-roo/
# Procesando: https://amlo.presidente.gob.mx/03-09-23-version-estenografica-inauguracion-de-obra-de-la-avenida-colosio-y-distribuidor-aeropuerto-cancun-desde-quintana-roo/
# Procesando: https://amlo.presidente.gob.mx/24-07-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-11-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-05-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-2/
# Procesando: https://amlo.presidente.gob.mx/30-09-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-01-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-11-19-version-estenografica-dialogo-con-pueblos-indigenas-desde-tlapa-de-comonfort-guerrero/
# Procesando: https://amlo.presidente.gob.mx/01-04-20-version-estenografica-inauguracion-del-hospital-rural-del-imss-bienestar-en-tlaxiaco-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/23-11-20-version-estenografica-dia-de-la-armada-de-mexico-desde-la-secretaria-de-marina-ciudad-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/05-04-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-06-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-morelia-michoacan/
# Procesando: https://amlo.presidente.gob.mx/11-08-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/25-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/06-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-03-21-version-estenografica-supervision-de-obra-del-tren-maya-desde-uayma-yucatan/
# Procesando: https://amlo.presidente.gob.mx/10-08-24-version-estenografica-inauguracion-de-hospital-general-del-imss-bienestar-desde-culiacan-sinaloa/
# Procesando: https://amlo.presidente.gob.mx/04-07-21-version-estenografica-plan-integral-de-atencion-a-cananea-y-programas-para-el-bienestar-desde-sonora/
# Procesando: https://amlo.presidente.gob.mx/03-04-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-03-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/12-01-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/04-08-24-version-estenografica-inauguracion-del-camino-minatitlan-hidalgotitlan-desde-veracruz/
# Procesando: https://amlo.presidente.gob.mx/29-05-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-07-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/22-11-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-09-19-version-estenografica-de-la-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/06-06-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/22-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-08-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/31-01-20-version-estenografica-construccion-del-gasoducto-cuxtal-fase-i-desde-reforma-chiapas/
# Procesando: https://amlo.presidente.gob.mx/13-05-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-03-20-version-estenografica-acciones-de-mejoramiento-urbano-desde-san-luis-rio-colorado-sonora/
# Procesando: https://amlo.presidente.gob.mx/18-11-21-version-estenografica-reunion-bilateral-mexico-estados-unidos-desde-washington-d-c/
# Procesando: https://amlo.presidente.gob.mx/24-03-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-07-21-version-estenografica-de-la-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/09-05-19-version-estenografica-de-la-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-05-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/10-06-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-05-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/15-08-19-version-estenografica-entrega-de-reconocimientos-a-la-delegacion-mexicana-de-los-juegos-panamericanos-de-lima-2019/
# Procesando: https://amlo.presidente.gob.mx/19-10-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-08-21-version-estenografica-inauguracion-de-instalaciones-de-la-guardia-nacional-desde-ahumada-chihuahua/
# Procesando: https://amlo.presidente.gob.mx/14-06-19-version-estenografica-programas-integrales-de-bienestar-y-zona-libre-de-la-frontera-norte-en-ojinaga-chihuahua/
# Procesando: https://amlo.presidente.gob.mx/14-02-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/03-04-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/12-04-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-02-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-06-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-08-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-villa-alta-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/01-02-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/01-10-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-cuernavaca-morelos/
# Procesando: https://amlo.presidente.gob.mx/25-05-19-version-estenografica-programas-integrales-de-bienestar-en-queretaro-queretaro/
# Procesando: https://amlo.presidente.gob.mx/26-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-07-19-version-estenografica-programas-integrales-de-bienestar-en-rioverde-san-luis-potosi/
# Procesando: https://amlo.presidente.gob.mx/23-07-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-05-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-10-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-03-21-version-estenografica-proyecto-integral-islas-marias-desde-nayarit/
# Procesando: https://amlo.presidente.gob.mx/01-08-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-03-21-version-estenografica-inauguracion-de-la-universidad-para-el-bienestar-desde-san-juan-bautista-valle-nacional-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/11-12-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-02-20-version-estenografica-nauguracion-de-instalaciones-de-la-guardia-nacional-desde-sahuayo-de-morelos-michoacan/
# Procesando: https://amlo.presidente.gob.mx/24-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-04-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-11-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-11-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-cancun-quintana-roo/
# Procesando: https://amlo.presidente.gob.mx/07-05-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/22-06-24-version-estenografica-inauguracion-del-camino-de-mano-de-obra-santa-catarina-coatlan-santa-ana-miahuatlan-desde-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/24-02-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-10-23-version-estenografica-programas-para-el-bienestar-desde-nezahualcoyotl-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/10-08-24-version-estenografica-inauguracion-de-la-clinica-hospital-issste-cabo-san-lucas-desde-baja-california-sur/
# Procesando: https://amlo.presidente.gob.mx/14-12-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-baja-california-sur/
# Procesando: https://amlo.presidente.gob.mx/04-06-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-palenque-chiapas/
# Procesando: https://amlo.presidente.gob.mx/03-02-20-version-estenografica-programa-de-mejoramiento-urbano-y-dialogo-con-pueblos-indigenas-desde-macuspana-tabasco/
# Procesando: https://amlo.presidente.gob.mx/13-04-21-version-estenografica-de-la-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/12-08-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/10-09-24-version-estenografica-primer-discurso-de-la-presidenta-electa-claudia-sheinbaum-pardo-a-las-fuerzas-armadas/
# Procesando: https://amlo.presidente.gob.mx/30-07-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-04-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/09-02-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/03-04-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/04-10-20-version-estenografica-programa-de-mejoramiento-urbano-desde-hermosillo-sonora/
# Procesando: https://amlo.presidente.gob.mx/20-06-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-02-22-version-estenografica-conclusion-de-obra-del-banco-del-bienestar-en-polotitlan-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/10-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-08-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-miahuatlan-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/14-03-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-08-19-version-estenografica-encuentro-con-empresarios-de-concamin-para-el-desarrollo-del-sur-sureste-del-pais/
# Procesando: https://amlo.presidente.gob.mx/14-12-19-version-estenografica-sembrando-vida-asamblea-ejidal-desde-jalapa-tabasco/
# Procesando: https://amlo.presidente.gob.mx/16-08-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/25-05-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-04-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-10-20-version-estenografica-visita-tecnica-a-la-presa-angel-albino-corzo-desde-ostucan-chiapas/
# Procesando: https://amlo.presidente.gob.mx/28-03-21-version-estenografica-acciones-de-rescate-y-recuperacion-de-agua-para-cuatro-cienegas-desde-coahuila/
# Procesando: https://amlo.presidente.gob.mx/06-01-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-09-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-03-21-version-estenografica-inauguracion-de-obras-en-el-puerto-de-coatzacoalcos-veracruz/
# Procesando: https://amlo.presidente.gob.mx/06-01-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-08-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-10-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-la-union-guerrero/
# Procesando: https://amlo.presidente.gob.mx/19-01-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-01-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-02-24-version-estenografica-programas-para-el-bienestar-desde-morelia-michoacan/
# Procesando: https://amlo.presidente.gob.mx/04-05-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-05-22-version-estenografica-tercera-jornada-nacional-de-sembrando-vida-desde-guadalupe-y-calvo-chihuahua/
# Procesando: https://amlo.presidente.gob.mx/16-08-24-version-estenografica-inauguracion-del-acueducto-armeria-manzanillo-desde-colima/
# Procesando: https://amlo.presidente.gob.mx/03-05-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-10-20-version-estenografica-acciones-de-mejoramiento-urbano-desde-cuernavaca-morelos/
# Procesando: https://amlo.presidente.gob.mx/17-09-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/06-06-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/11-06-21-version-estenografica-programas-integrales-de-bienestar-desde-florencio-villarreal-guerrero/
# Procesando: https://amlo.presidente.gob.mx/24-06-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-09-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-12-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-12-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/23-12-19-version-estenografica-visita-a-la-lumbrera-19-del-tunel-emisor-oriente-desde-huehuetoca-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/14-02-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/04-01-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/09-12-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/25-09-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-10-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-03-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/10-06-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-2/
# Procesando: https://amlo.presidente.gob.mx/15-11-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-06-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-10-23-version-estenografica-encuentro-con-especialistas-en-zona-arqueologica-de-uxmal-desde-yucatan/
# Procesando: https://amlo.presidente.gob.mx/15-06-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-xalapa-veracruz/
# Procesando: https://amlo.presidente.gob.mx/23-12-19-version-estenografica-de-la-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-02-23-version-estenografica-inauguracion-de-la-modernizacion-del-camino-agua-prieta-bavispe-desde-sonora/
# Procesando: https://amlo.presidente.gob.mx/28-06-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/11-11-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-colima/
# Procesando: https://amlo.presidente.gob.mx/30-10-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/01-10-23-version-estenografica-programas-para-el-bienestar-desde-valle-de-chalco-solidaridad-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/25-07-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-11-23-version-estenografica-reunion-con-autoridades-tradicionales-yaquis-desde-guaymas-sonora/
# Procesando: https://amlo.presidente.gob.mx/23-02-20-version-estenografica-congreso-nacional-extraordinario-de-la-ctm-desde-el-monumento-a-la-revolucion/
# Procesando: https://amlo.presidente.gob.mx/20-07-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/23-11-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-09-20-version-estenografica-evaluacion-de-programas-integrales-de-bienestar-desde-veracruz-veracruz/
# Procesando: https://amlo.presidente.gob.mx/08-04-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-04-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-mazatlan-sinaloa/
# Procesando: https://amlo.presidente.gob.mx/21-05-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-03-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/01-10-23-version-estenografica-programas-para-el-bienestar-desde-ixtapaluca-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/11-12-20-version-estenografica-inauguracion-del-camino-rural-santo-domingo-nuxaa-desde-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/03-01-20-version-estenografica-dialogo-con-pueblos-indigenas-desde-san-pablo-del-monte-tlaxcala/
# Procesando: https://amlo.presidente.gob.mx/13-01-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-03-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-09-20-version-estenografica-evaluacion-de-programas-integrales-de-bienestar-desde-cordoba-veracruz/
# Procesando: https://amlo.presidente.gob.mx/22-07-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-09-21-version-estenografica-inauguracion-de-sucursal-del-banco-del-bienestar-en-tlahuac-ciudad-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/04-08-24-version-estenografica-inauguracion-de-carretera-acayucan-la-ventosa-desde-veracruz/
# Procesando: https://amlo.presidente.gob.mx/31-08-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-chignahuapan-puebla/
# Procesando: https://amlo.presidente.gob.mx/26-05-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/10-06-23-version-estenografica-programas-para-el-bienestar-desde-tamazunchale-san-luis-potosi/
# Procesando: https://amlo.presidente.gob.mx/25-08-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-09-24-version-estenografica-entrega-de-acueducto-y-distrito-de-riego-al-pueblo-yaqui-desde-guaymas-sonora/
# Procesando: https://amlo.presidente.gob.mx/27-10-23-version-estenografica-programas-para-el-bienestar-desde-atizapan-de-zaragoza-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/04-06-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-12-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez/
# Procesando: https://amlo.presidente.gob.mx/21-07-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-chicontepec-en-veracruz/
# Procesando: https://amlo.presidente.gob.mx/11-10-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-08-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-11-22-version-estenografica-plan-nacional-de-salud-imss-bienestar-desde-acapulco-guerrero/
# Procesando: https://amlo.presidente.gob.mx/12-10-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-san-quintin-ensenada-baja-california/
# Procesando: https://amlo.presidente.gob.mx/30-03-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-08-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-04-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/11-06-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-09-23-version-estenografica-programas-para-el-bienestar-desde-texcoco-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/01-12-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-05-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/01-03-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-07-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-04-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/03-01-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-yucatan/
# Procesando: https://amlo.presidente.gob.mx/31-05-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/09-08-19-version-estenografica-de-la-conferencia-de-prensa-matutina-desde-durango-del-presidente-andres-manuel-lopez-obrada/
# Procesando: https://amlo.presidente.gob.mx/27-03-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-03-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-12-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-campeche/
# Procesando: https://amlo.presidente.gob.mx/02-02-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/25-06-19-version-estenografica-programas-integrales-de-bienestar-en-ecatepec-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/17-11-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-07-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-10-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-tlaxiaco-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/08-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/23-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/01-03-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-03-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-07-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-12-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-10-19-version-estenografica-dialogo-con-pueblos-indigenas-desde-guaymas-sonora/
# Procesando: https://amlo.presidente.gob.mx/16-02-20-version-estenografica-inauguracion-de-instalaciones-de-la-guardia-nacional-desde-romita-guanajuato/
# Procesando: https://amlo.presidente.gob.mx/17-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/12-07-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-san-cayetano-en-tepic-nayarit/
# Procesando: https://amlo.presidente.gob.mx/19-12-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-06-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-10-20-version-estenografica-remodelacion-y-ampliacion-de-la-clinica-hospital-issste-de-piedras-negras-desde-coahuila/
# Procesando: https://amlo.presidente.gob.mx/15-11-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-12-20-version-estenografica-inauguracion-de-la-planta-potabilizadora-miravalles-y-acueducto-picachos-desde-mazatlan-sinaloa/
# Procesando: https://amlo.presidente.gob.mx/21-01-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-08-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-queretaro/
# Procesando: https://amlo.presidente.gob.mx/22-07-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-09-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-09-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-06-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/03-02-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-11-19-version-estenografica-60-entrega-de-premios-antena-semana-de-la-radio-y-la-television/
# Procesando: https://amlo.presidente.gob.mx/01-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-10-20-version-estenografica-inicio-de-construccion-de-la-unidad-de-medicina-familiar-no-12-desde-agua-prieta-sonora/
# Procesando: https://amlo.presidente.gob.mx/12-10-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-08-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/21-04-24-version-estenografica-110-aniversario-de-la-defensa-del-puerto-de-veracruz/
# Procesando: https://amlo.presidente.gob.mx/27-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-06-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-04-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-2/
# Procesando: https://amlo.presidente.gob.mx/19-10-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-09-24-version-estenografica-de-la-ultima-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-11-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/23-06-19-version-estenografica-programas-integrales-de-bienestar-y-tren-maya-en-tulum-quintana-roo/
# Procesando: https://amlo.presidente.gob.mx/04-11-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-02-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/15-09-23-version-estenografica-inauguracion-de-el-insurgente-tren-interurbano-mexico-toluca/
# Procesando: https://amlo.presidente.gob.mx/22-07-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-08-22-version-estenografica-plan-de-justicia-para-el-pueblo-yaqui-desde-guaymas-sonora/
# Procesando: https://amlo.presidente.gob.mx/04-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-puebla-puebla/
# Procesando: https://amlo.presidente.gob.mx/20-02-22-version-estenografica-reunion-con-autoridades-de-la-montana-de-guerrero/
# Procesando: https://amlo.presidente.gob.mx/05-06-20-version-estenografica-evaluacion-de-trabajos-de-la-refineria-dos-bocas-desde-paraiso-tabasco/
# Procesando: https://amlo.presidente.gob.mx/16-02-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/22-09-24-version-estenografica-inauguracion-del-centro-cultural-leyes-de-reforma-desde-veracruz/
# Procesando: https://amlo.presidente.gob.mx/27-04-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-03-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-05-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-02-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-03-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-10-19-version-estenografica-de-la-conferencia-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/11-11-23-version-estenografica-programas-para-el-bienestar-desde-san-felipe-baja-california/
# Procesando: https://amlo.presidente.gob.mx/27-10-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/25-03-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-06-21-version-estenografica-ampliacion-del-hospital-rural-san-quintin-imss-bienestar-desde-baja-california/
# Procesando: https://amlo.presidente.gob.mx/12-07-19-version-estenografica-de-la-conferencia-de-prensa-matutina-desde-tepic-nayarit-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/22-09-21-version-estenografica-feria-aeroespacial-mexico-2021/
# Procesando: https://amlo.presidente.gob.mx/14-07-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-coalcoman-en-michoacan/
# Procesando: https://amlo.presidente.gob.mx/15-03-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-02-24-version-estenografica-programas-para-el-bienestar-desde-atoyac-de-alvarez-guerrero/
# Procesando: https://amlo.presidente.gob.mx/24-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/04-05-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/09-12-23-version-estenografica-programas-para-el-bienestar-desde-tejupilco-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/07-09-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manual-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-12-20-version-estenografica-supervision-de-obra-del-tren-maya-desde-palenque-chiapas/
# Procesando: https://amlo.presidente.gob.mx/21-09-24-version-estenografica-inauguracion-del-camino-benito-juarez-e-informe-del-programa-caminos-artesanales/
# Procesando: https://amlo.presidente.gob.mx/25-01-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-09-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-11-19-version-estenografica-dialogo-con-pueblos-indigenas-desde-la-yesca-nayarit/
# Procesando: https://amlo.presidente.gob.mx/17-06-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/06-03-20-version-estenografica-programas-integrales-de-bienestar-desde-mexquitic-san-luis-potosi/
# Procesando: https://amlo.presidente.gob.mx/12-07-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-04-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-04-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-07-19-version-estenografica-firma-de-convenio-para-el-desarrollo-de-la-huasteca-potosina/
# Procesando: https://amlo.presidente.gob.mx/31-01-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/12-06-21-version-estenografica-supervision-autopista-barranca-larga-ventanilla-desde-san-vicente-coatlan-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/19-09-20-version-estenografica-programa-nacional-de-reconstruccion-a-tres-anos-de-los-sismos-de-2017-desde-puebla/
# Procesando: https://amlo.presidente.gob.mx/29-06-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/11-02-23-version-estenografica-reunion-bilateral-mexico-cuba-salud-imss-bienestar-desde-campeche/
# Procesando: https://amlo.presidente.gob.mx/02-04-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-07-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/10-12-21-version-estenografica-instalacion-de-comision-para-el-acceso-a-la-verdad-y-el-impulso-a-la-justicia-desde-chihuahua/
# Procesando: https://amlo.presidente.gob.mx/25-09-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/22-02-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-01-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-02-20-version-estenografica-inauguracion-de-instalaciones-de-la-guardia-nacional-desde-penjamo-guanajuato/
# Procesando: https://amlo.presidente.gob.mx/10-08-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-09-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/23-02-24-version-estenografica-inauguracion-del-acueducto-picachos-concordia-desde-sinaloa/
# Procesando: https://amlo.presidente.gob.mx/17-10-20-version-estenografica-ampliacion-del-aeropuerto-internacional-angel-albino-corzo-en-chiapas/
# Procesando: https://amlo.presidente.gob.mx/16-04-23-version-estenografica-programa-nacional-de-caminos-de-mano-de-obra-desde-coxcaltepec-cantaros-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/08-07-19-version-estenografica-primera-sesion-ordinaria-del-consejo-nacional-de-proteccion-civil/
# Procesando: https://amlo.presidente.gob.mx/14-06-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/27-06-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-03-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/21-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-05-22-version-estenografica-ceremonia-de-homenaje-postumo-a-arnoldo-martinez-verdugo-desde-la-rotonda-de-las-personas-ilustres/
# Procesando: https://amlo.presidente.gob.mx/29-09-21-version-estenografica-inauguracion-de-sucursal-del-banco-del-bienestar-en-iztapalapa-ciudad-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/07-09-24-version-estenografica-inauguracion-del-museo-historico-de-la-ciudad-de-felipe-carrillo-puerto-desde-quintana-roo/
# Procesando: https://amlo.presidente.gob.mx/24-10-20-version-estenografica-visita-tecnica-a-la-central-termoelectica-jose-lopez-portillo-desde-nava-coahuila/
# Procesando: https://amlo.presidente.gob.mx/04-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# ...
# Procesando: https://amlo.presidente.gob.mx/15-01-21-version-estenografica-visita-al-recinto-portuario-de-lazaro-cardenas-desde-michoacan/
# Procesando: https://amlo.presidente.gob.mx/31-05-19-version-estenografica-programas-integrales-de-bienestar-en-apizaco-tlaxcala/
# Procesando: https://amlo.presidente.gob.mx/19-10-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-09-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-04-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-01-20-version-estenografica-inauguracion-del-camino-rural-santa-maria-tepantlali-y-dialogo-con-el-pueblo-mixe-desde-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/24-06-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/21-07-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/09-12-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-06-21-version-estenografica-supervision-de-obra-de-autopista-mitla-tehuantepec-desde-santo-domingo-tepuxtepec-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/14-07-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/23-10-21-version-estenografica-reunion-con-autoridades-de-la-montana-de-guerrero-desde-tlapa/
# Procesando: https://amlo.presidente.gob.mx/11-08-24-version-estenografica-nayarit-proyectos-prioritarios-y-de-infraestructura/
# Procesando: https://amlo.presidente.gob.mx/10-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/22-02-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-08-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-01-20-version-estenografica-inauguracion-de-la-universidad-para-el-bienestar-benito-juarez-desde-juan-r-escudero-guerrero/
# Procesando: https://amlo.presidente.gob.mx/23-11-19-version-estenografica-dia-de-la-armada-de-mexico-desde-la-rotonda-de-las-personas-ilustres-ciudad-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/28-07-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-zongolica-en-veracruz/
# Procesando: https://amlo.presidente.gob.mx/19-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/10-08-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-villanueva-zacatecas/
# Procesando: https://amlo.presidente.gob.mx/25-03-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-campeche/
# Procesando: https://amlo.presidente.gob.mx/20-06-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-07-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-veracruz/
# Procesando: https://amlo.presidente.gob.mx/06-11-20-version-estenografica-supervision-de-obra-en-carretera-federal-la-yesca-desde-nayarit/
# Procesando: https://amlo.presidente.gob.mx/19-07-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/04-08-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/15-06-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-05-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-12-19-version-estenografica-visita-a-la-central-de-ciclo-combinado-el-sauz-desde-pedro-escobedo-queretaro/
# Procesando: https://amlo.presidente.gob.mx/28-04-22-version-estenografica-125-asamblea-general-ordinaria-del-infonavit-desde-palacio-nacional/
# Procesando: https://amlo.presidente.gob.mx/03-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-08-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/21-10-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/15-02-20-version-estenografica-inauguracion-de-instalaciones-de-la-guardia-nacional-en-tepatitlan-de-morelos-jalisco/
# Procesando: https://amlo.presidente.gob.mx/20-10-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-11-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/03-10-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-12-20-version-estenografica-inauguracion-de-instalaciones-de-la-guardia-nacional-desde-moctezuma-sonora/
# Procesando: https://amlo.presidente.gob.mx/14-08-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/15-06-20-version-estenografica-sembrando-vida-desde-perote-veracruz/
# Procesando: https://amlo.presidente.gob.mx/29-03-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-08-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/21-08-22-version-estenografica-reunion-con-autoridades-de-la-sierra-de-sonora-y-chihuahua/
# Procesando: https://amlo.presidente.gob.mx/22-05-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-10-21-version-estenografica-plan-de-apoyo-a-personas-afectadas-por-el-huracan-grace-en-hidalgo/
# Procesando: https://amlo.presidente.gob.mx/22-10-21-version-estenografica-reunion-con-autoridades-de-la-montana-de-guerrero/
# Procesando: https://amlo.presidente.gob.mx/06-12-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/13-06-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-01-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-03-20-version-estenografica-dialogo-con-el-pueblo-afromexicano-desde-cuajinicuilapa-guerrero/
# Procesando: https://amlo.presidente.gob.mx/31-07-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/06-03-21-version-estenografica-supervision-de-obra-del-tren-maya-desde-campeche/
# Procesando: https://amlo.presidente.gob.mx/18-07-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-08-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/08-12-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-nayarit/
# Procesando: https://amlo.presidente.gob.mx/26-08-19-version-estenografica-inicio-del-ciclo-escolar-2019-2020-desde-la-escuela-melchor-ocampo-cdmx/
# Procesando: https://amlo.presidente.gob.mx/04-02-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-12-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-04-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/12-09-20-version-estenografica-inauguracion-de-la-linea-3-del-tren-ligero-de-guadalajara-desde-tonala-jalisco/
# Procesando: https://amlo.presidente.gob.mx/30-04-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/25-05-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-03-21-version-estenografica-evaluacion-del-programa-sembrando-vida-desde-santa-maria-jaltianguis-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/21-02-21-version-estenografica-inauguracion-de-unidades-de-generacion-turbogas-aeroderivadas-desde-la-paz-baja-california-sur/
# Procesando: https://amlo.presidente.gob.mx/10-04-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/28-09-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador-desde-oaxaca-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/19-04-24-version-estenografica-87-convencion-bancaria-desde-acapulco-guerrero/
# Procesando: https://amlo.presidente.gob.mx/16-02-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/05-12-22-version-estenografica-plan-de-salud-imss-bienestar-desde-escarcega-campeche/
# Procesando: https://amlo.presidente.gob.mx/26-02-21-version-estenografica-de-la-conferencia-de-prensa-matutina-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/15-08-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/24-01-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/04-12-20-version-estenografica-supervision-del-canal-centenario-desde-ruiz-nayarit/
# Procesando: https://amlo.presidente.gob.mx/06-09-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-07-24-version-estenografica-evaluacion-del-programa-nacional-de-reconstruccion-tlaquiltenango-morelos/
# Procesando: https://amlo.presidente.gob.mx/18-06-21-version-estenografica-supervision-de-obra-autopista-cardel-poza-rica-desde-martinez-de-la-torre-veracruz/
# Procesando: https://amlo.presidente.gob.mx/02-03-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/16-04-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/07-07-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/18-08-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/02-09-24-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/10-08-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/26-10-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/25-07-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/20-07-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/03-02-22-version-estenografica-inauguracion-de-sucursal-del-banco-del-bienestar-en-cuautepec-de-hinojosa-hidalgo/
# Procesando: https://amlo.presidente.gob.mx/06-09-19-version-estenografica-dialogo-con-la-comunidad-del-hospital-rural-charcas-san-luis-potosi/
# Procesando: https://amlo.presidente.gob.mx/10-02-24-version-estenografica-dia-de-la-fuerza-aerea-mexicana-desde-zumpango-estado-de-mexico/
# Procesando: https://amlo.presidente.gob.mx/12-02-21-version-estenografica-primera-etapa-de-la-universidad-benito-juarez-desde-zinacatepec-puebla/
# Procesando: https://amlo.presidente.gob.mx/08-12-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/31-10-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/04-09-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/19-09-22-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/30-05-19-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/14-08-22-version-estenografica-plan-de-apoyo-agua-para-nuevo-leon/
# Procesando: https://amlo.presidente.gob.mx/20-09-19-version-estenografica-de-la-conferencia-de-prensa-del-presidente-andres-manuel-lopez-obrador-desde-merida-yucatan/
# Procesando: https://amlo.presidente.gob.mx/23-12-21-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/29-06-19-version-estenografica-supervision-de-construccion-de-caminos-a-cabeceras-municipales-en-san-juan-atepec-oaxaca/
# Procesando: https://amlo.presidente.gob.mx/11-06-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
# Procesando: https://amlo.presidente.gob.mx/17-10-19-version-estenografica-inicio-de-la-construccion-del-aeropuerto-general-felipe-angeles-desde-la-bam-santa-lucia/
# Procesando: https://amlo.presidente.gob.mx/19-12-23-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/
#
# Número de conferencias que no se pudieron descargar: 1
# URLs de las conferencias fallidas:
# https://amlo.presidente.gob.mx/03-07-20-version-estenografica-de-la-conferencia-de-prensa-matutina-del-presidente-andres-manuel-lopez-obrador/

# %% [markdown]
# ### Versiones estenografica de Claudia Sheinbaum Pardo

# %%
url_pagina_i = 'https://www.gob.mx/presidencia/es/archivo/articulos?idiom=es&order=DESC&page='
num_pag = 16 #hasta la fecha actual 27-enero-2025, solo hay 16 paginas 

workdir = os.getcwd()
paginas_dir = os.path.join(workdir, "paginas_sheinbaum")
if not os.path.exists(paginas_dir):
    os.makedirs(paginas_dir)

for i in range(num_pag):
    wget.download(url= url_pagina_i + str(i+1), out = "./paginas_sheinbaum/" + str(i+1) + ".txt")

# %%
for file_pagina in glob.glob('./paginas_sheinbaum/*'):
    with open(file_pagina, 'r', encoding='utf-8') as f:
        content = f.read()
        print(f"Contenido de {file_pagina}:\n{content[:500]}\n")
# Out:
# Contenido de ./paginas_sheinbaum\1.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\10.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\11.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\12.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\13.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\14.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\15.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\16.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\2.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\3.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\4.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\5.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\6.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\7.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\8.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">
#
#
# Contenido de ./paginas_sheinbaum\9.txt:
# <!DOCTYPE html>
# <html class='no-js' lang='es'>
# <head>
#     <title>
#   Blog | Archivo | Presidencia de la República  | Gobierno | gob.mx
# </title>
#
#   <meta charset='UTF-8'>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="theme-color" content="#393C3E">
#
#
#   <meta content="Archivo Blog" property="og:title" />
#   <meta name="description" content="Archivo de artículos de Presidencia de la República ">

# %% [markdown]
# #### Extrar urls

# %%
def extraer_urls(ruta_archivo):
    """Extrae e imprime todos los URLs presentes en un archivo de texto."""
    pattern = r'https?://[^\s"]+'
    
    with open(ruta_archivo, 'r', encoding='utf-8') as f:
        contenido = f.read()
        urls = re.findall(pattern, contenido)
    
    if urls:
        print("\n".join(urls))
    else:
        print(f"No se encontraron URLs en {ruta_archivo}")

ruta_archivo = os.path.join(workdir, "paginas_sheinbaum", "1.txt")
extraer_urls(ruta_archivo)
# Out:
# https://fonts.googleapis.com/css?family=Open+Sans:400,700,600,300'
# https://framework-gb.cdn.gob.mx/applications/cms/favicon.png'
# https://framework-gb.cdn.gob.mx/gm/accesibilidad/css/gobmx-accesibilidad.min.css
# https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js
# https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js
# https://www.googletagmanager.com/gtag/js?id=G-M3KVJ03TMZ
# https://framework-gb.cdn.gob.mx/applications/cms/carrusel/swiper-bundle.min.js
# https://framework-gb.cdn.gob.mx/applications/cms/carrusel/swiper-bundle.min.css
# https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.6.0/slick.js
# https://s.go-mpulse.net/boomerang/
# https://s2.go-mpulse.net/boomerang/
# https://connect.facebook.net/es_LA/sdk.js#xfbml=1&version=v13.0
# https://www.gob.mx/busqueda?utf8=✓
# https://framework-gb.cdn.gob.mx/landing/img/lupa.png
# https://transparencia.presidencia.gob.mx/presidencia/transparencia/politicas-de-tratamiento-de-datos-personales-de-la-oficina-de-la-presidencia-de-la-republica/'>
# https://transparencia.presidencia.gob.mx/'>
# http://www.gob.mx
# https://www.gob.mx/presidencia/es/archivo/articulos?idiom=es&amp;order=DESC&amp;page=1
# https://www.gob.mx/presidencia/es/archivo/articulos?idiom=es&amp;order=DESC&amp;page=1
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/153130/cover_CM_CSP.jpeg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/153124/cover_presidenta_CSP_Oaxaca.jpeg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/153123/cover_2025-01-25_Programas_para_el_Bienestar_-_Santiago_Juxtlahuaca_-_Oaxaca_24.jpg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/153098/cover_Inauguracion_carretera_Mitla_Tehuantepec.jpeg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/153083/cover_Presidenta_Claudia_Sheinbaum.jpeg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/153059/cover_2025-01-23_Conferencia_de_prensa_matutina_-_Palacio_Nacional_24.jpg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/153003/cover_2025-01-22_Conferencia_de_prensa_matutina_-_Palacio_Nacional_04.jpg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/152975/cover_2025-01-21_Conferencia_de_prensa_matutina_-_Palacio_Nacional_08.jpg
# https://framework-gb.cdn.gob.mx/main/missing-photo.jpg&#39;;
# https://www.gob.mx/cms/uploads/article/main_image/152944/cover_WhatsApp_Image_2025-01-20_at_9.33.55_AM.jpeg
# https://framework-gb.cdn.gob.mx/assets/scripts/jquery-ui-datepicker.js
# https://framework-gb.cdn.gob.mx/gobmx/img/logo_blanco.svg
# http://www.participa.gob.mx
# https://datos.gob.mx/
# https://www.gob.mx/publicaciones
# https://consultapublicamx.plataformadetransparencia.org.mx/vut-web/faces/view/consultaPublica.xhtml?idEntidad=MzM=&amp;idSujetoObligado=MTAwMDE=#inicio
# https://www.infomex.org.mx/gobiernofederal/home.action
# http://www.inai.org.mx/
# http://alertadores.funcionpublica.gob.mx/
# http://sidec.funcionpublica.gob.mx/
# http://www.gob.mx/epn'>
# http://www.ordenjuridico.gob.mx
# https://www.facebook.com/gobmexico
# https://framework-gb.cdn.gob.mx/landing/img/facebook.png
# https://twitter.com/GobiernoMX
# https://framework-gb.cdn.gob.mx/landing/img/twitter.png
# https://www.instagram.com/gobmexico/
# https://www.youtube.com/@gobiernodemexico
# https://sb
# http://b
# https://sb.scorecardresearch.com/p?c1=2&c2=17183199&cv=2.0&cj=1
# https://sb.scorecardresearch.com/c2/17183199/ct.js
# https://sb.scorecardresearch.com/p?c1=2&c2='+ui_c2+'&ns_site='+ui_ns_site+'&name='+a+'&ns_type=hidden&type=hidden&ns_ui_type='+b;
# https://sb.scorecardresearch.com/b?c1=2&c2=17183199&ns_site=gobmx&name='+siteEls);
# https://sb.scorecardresearch.com/p?c1=2&amp;c2=17183199&amp;ns_site=gobmx&amp;name=gobierno.presidencia.es.archivo.articulos
# https://framework-gb.cdn.gob.mx/applications/cms/configGobmx.json
# https://framework-gb.cdn.gob.mx/applications/cms/modal_global_cms.js
# https://framework-gb.cdn.gob.mx/gm/accesibilidad/js/gobmx-accesibilidad.min.js
# https://framework-gb.cdn.gob.mx/assets/scripts/vendor/slick.js
# https://framework-gb.cdn.gob.mx/assets/scripts/vendor/slick.min.js
# https://framework-gb.cdn.gob.mx/assets/scripts/vendor/slick-lightbox.js
# https://framework-gb.cdn.gob.mx/assets/scripts/vendor/slick-lightbox.css
# https://framework-gb.cdn.gob.mx/applications/cms/config_dependency.js

# %% [markdown]
# Los urls de las conferencias estan asociados cuando ocurre el evento (Botón) "Continuar leyendo"

# %%
def extraer_urls_versiones_estenograficas(archivo):
    """Extrae e imprime los URLs completos de las versiones estenográficas desde un archivo HTML."""
    workdir = os.getcwd()
    ruta_archivo = os.path.join(workdir, archivo)

    with open(ruta_archivo, 'r', encoding='utf-8') as f:
        contenido = f.read()

    # Parsear el HTML con BeautifulSoup
    soup = BeautifulSoup(contenido, 'html.parser')

    # Buscar todos los enlaces que contienen el texto "Continuar Leyendo"
    enlaces = soup.find_all('a', string=re.compile("Continuar Leyendo", re.IGNORECASE))

    base_url = "https://www.gob.mx"

    # Construir urls 
    urls = [
        enlace['href'] if enlace['href'].startswith("http") else base_url + enlace['href']
        for enlace in enlaces if enlace.has_attr('href')]

    if urls:
        print("\n".join(urls))
    else:
        print(f"No se encontraron URLs en {ruta_archivo}")

# Ejemplo (insight)
extraer_urls_versiones_estenograficas("paginas_sheinbaum/2.txt")
# Out:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-para-el-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-recorrido-por-el-centro-de-rehabilitacion-e-inclusion-teleton-crit-de-tlapa-de-comonfort-guerrero?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-arranque-del-programa-nacional-de-fertilizantes-para-el-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-la-pension-mujeres-bienestar-388297?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-jovenes-construyendo-el-futuro?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-centro-integral-para-el-programa-acapulco-se-transforma-contigo?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-encuentro-nacional-municipal?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-enero-de-2025?idiom=es

# %%
def extraer_urls_versiones_estenograficas(archivo):
    """Extrae los URLs completos de las versiones estenográficas desde un archivo HTML."""
    with open(archivo, 'r', encoding='utf-8') as f:
        contenido = f.read()

    # Parsear el HTML con BeautifulSoup
    soup = BeautifulSoup(contenido, 'html.parser')

    # Buscar todos los enlaces que contienen el texto "Continuar Leyendo"
    enlaces = soup.find_all('a', string=re.compile("Continuar Leyendo", re.IGNORECASE))

    base_url = "https://www.gob.mx"

    # Construir urls
    urls = [
        enlace['href'] if enlace['href'].startswith("http") else base_url + enlace['href']
        for enlace in enlaces if enlace.has_attr('href')
    ]

    return urls

num_pag = 16
workdir = os.getcwd()
paginas_dir = os.path.join(workdir, "paginas_sheinbaum")

archivos_txt = [os.path.join(paginas_dir, f) for f in os.listdir(paginas_dir) if f.endswith('.txt')]

todos_los_urls = []
for archivo in archivos_txt:
    urls_encontradas = extraer_urls_versiones_estenograficas(archivo)
    if urls_encontradas:
        print(f"URLs encontradas en {archivo}:")
        print("\n".join(urls_encontradas))
        todos_los_urls.extend(urls_encontradas)

# Guardar urls en un txt 
output_file = os.path.join(workdir, "conferencias_urls_sheinbaum.txt")
with open(output_file, "w", encoding="utf-8") as f:
    for url in todos_los_urls:
        f.write(url + "\n")
# Out:
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\1.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-pension-mujeres-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-388896?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-carretera-mitla-tehuantepec?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-24-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-enero-de-2025?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\10.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-199-aniversario-de-la-consolidacion-de-la-independencia-en-el-mar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-114-aniversario-de-la-revolucion-mexicana?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-primera-sesion-de-trabajo-lucha-contra-el-hambre-y-la-pobreza-en-la-cumbre-del-g20?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-segunda-sesion-de-trabajo-reforma-de-las-instituciones-de-gobernanza-global-en-la-cumbre-del-g20?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-noviembre-de-2024?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\11.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-original-encuentro-de-arte-textil-mexicano-en-palacio-nacional?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-12-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-encuentro-con-el-pueblo-de-zacatecas?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-unidad-de-medicina-familiar-no-58?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programa-de-apoyo-al-campo?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-camino-artesanal-pata-de-gallo-santiago-teneraca-primera-etapa-en-mezquital-durango?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\12.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-5-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-31-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-30-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-29-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-octubre-de-2024?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\13.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-informe-general-de-las-acciones-por-el-huracan-john-en-acapulco-guerrero?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-en-playas-de-rosarito-baja-california?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-hospital-general-santa-rosalia?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-25-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-24-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar-y-convenio-pension-universal-para-personas-con-discapacidad-en-yucatan?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\14.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-en-escarcega-campeche?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar-y-convenio-pension-universal-para-personas-con-discapacidad?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-18-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-resultados-de-la-cumbre-dialogo-ceo-mexico-estados-unidos?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inicio-de-trabajos-preliminares-para-la-construccion-del-tren-mexico-queretaro?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\15.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-apoyo-bimestral-para-mujeres-de-60-a-64-anos?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-ceremonia-conmemorativa-de-los-200-anos-de-la-republica?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inicio-de-trabajos-preliminares-tren-mexico-pachuca?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-en-morelos?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\16.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-200-anos-de-la-promulgacion-de-la-constitucion-federal-de-1824-y-creacion-de-la-armada-de-mexico-379875?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-salutacion-de-las-fuerzas-armadas-y-guardia-nacional-a-la-presidenta-constitucional-de-los-estados-unidos-mexicanos?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-la-presidenta-claudia-sheinbaum-pardo-del-2-de-octubre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-toma-de-protesta-ante-el-pueblo-de-mexico?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-mensaje-de-la-presidenta-de-los-estados-unidos-mexicanos-claudia-sheinbaum-pardo?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-toma-de-protesta-de-claudia-sheinbaum-como-presidenta-constitucional-de-los-estados-unidos-mexicanos?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\2.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-para-el-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-recorrido-por-el-centro-de-rehabilitacion-e-inclusion-teleton-crit-de-tlapa-de-comonfort-guerrero?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-arranque-del-programa-nacional-de-fertilizantes-para-el-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-la-pension-mujeres-bienestar-388297?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-jovenes-construyendo-el-futuro?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-centro-integral-para-el-programa-acapulco-se-transforma-contigo?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-encuentro-nacional-municipal?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-enero-de-2025?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\3.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-presentacion-del-plan-mexico-en-el-museo-nacional-de-antropologia?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-informe-100-dias-de-gobierno?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-si-al-desarme-si-a-la-paz-en-la-basilica-de-guadalupe?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-enero-de-2025-387640?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-enero-de-2025?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\4.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-reapertura-del-segundo-piso-del-museo-nacional-de-antropologia-grandeza-y-diversidad-cultural-de-mexico?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-del-bienestar-387268?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-la-pension-mujeres-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-del-bienestar?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-pension-mujeres-bienestar-zinacantepec-estado-de-mexico?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-enero-de-2025?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\5.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-2-de-enero-de-2025?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-30-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-386975?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-autopista-jala-puerto-vallarta?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-386732?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-la-universidad-del-pueblo-yaqui?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\6.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-hospital-general-regional-no-02?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-restitucion-de-tierras-a-la-comunidad-raramuri-y-plan-de-justicia-para-pueblos-de-la-sierra-tarahumara?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-19-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-18-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-1-aniversario-del-tren-maya-e-inauguracion-de-los-tramos-6-y-7?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inicio-de-la-construccion-del-parque-ecoturistico-la-ceiba?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\7.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-titulos-profesionales-a-egresados-de-universidades-benito-juarez?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-115-asamblea-general-ordinaria-del-imss?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-construccion-del-cecyt-20-natalia-serdan-y-upii-alejo-peralta?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-consejo-nacional-de-seguridad-publica?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-385510?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\8.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-centro-de-salud-docente-con-servicios-ampliados-de-santiago-astata-oaxaca?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-autopista-tuxtla-san-cristobal?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-5-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-firma-de-convenio-entre-el-gobierno-de-mexico-y-la-fundacion-teleton-a-c?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-2-de-diciembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-hospital-imss-bienestar-de-salud-mental-dr-victor-m-concha-vasquez?idiom=es
# URLs encontradas en C:\Users\ericl\tareas_nlp\paginas_sheinbaum\9.txt:
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-unidad-de-medicina-familiar-no-73?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-29-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-28-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-premio-nacional-de-deportes-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-acuerdo-nacional-por-el-derecho-humano-al-agua-y-la-sustentabilidad?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-25-de-noviembre-de-2024?idiom=es
# https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar-en-alvaro-obregon-michoacan?idiom=es

# %%
# %pip install locate
# Out:
# Collecting locate
#   Downloading locate-1.1.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading locate-1.1.1-py3-none-any.whl (5.4 kB)
# Installing collected packages: locate
# Successfully installed locate-1.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import locale  
locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')

output_folder = "versiones_estenograficas_sheinbaum"
os.makedirs(output_folder, exist_ok=True)

with open('conferencias_urls_sheinbaum.txt', 'r', encoding='utf-8') as file:
    urls = [line.strip() for line in file]

print(f'Conferencias encontradas: {len(set(urls))}')
# Out:
# Conferencias encontradas: 143

# %% [markdown]
# #### Extraer texto relevante por conferencia

# %%
def extraer_fecha(soup):
    """
    Extrae la fecha del contenido HTML.
    La fecha está en un elemento <p> que contiene "Presidencia de la República".
    """
    # Buscar el elemento <p> que contiene "Presidencia de la República"
    fecha_element = soup.find("p", string=lambda x: x and "Presidencia de la República" in x)
    
    if fecha_element:
        fecha_texto = fecha_element.get_text(strip=True)
        fecha = fecha_texto.split("|")[-1].strip()  # Extraer la fecha después del carácter "|"
        try:
            # Convertir la fecha a formato estándar (YYYY-MM-DD)
            fecha_formateada = datetime.strptime(fecha, "%d de %B de %Y").strftime("%Y-%m-%d")
            return fecha_formateada
        except ValueError as e:
            print(f"Error al convertir la fecha '{fecha}': {e}")
    return None

# %%
# %%time
fallidos = []

for url in urls:
    print(f"Procesando: {url}")
    try:
        response = requests.get(url)
        
        if response.status_code == 200:
            # Parsear el contenido HTML de la página
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Buscar el contenido relevante
            contenido_relevante = soup.find("div", class_="article-body")
            fecha = extraer_fecha(soup)
            
            if contenido_relevante and fecha:
                texto = contenido_relevante.get_text(strip=True)
                
                # Extraer el nombre del archivo del URL y agregar la fecha
                nombre_archivo = url.split("/articulos/")[-1].split("?")[0]
                nombre_archivo_con_fecha = f"{fecha}_{nombre_archivo}"
                archivo_salida = os.path.join(output_folder, f"{nombre_archivo_con_fecha}.txt")
                
                # Guardar el contenido en un archivo
                with open(archivo_salida, 'w', encoding='utf-8') as output_file:
                    output_file.write(texto)
                print(f"Archivo guardado: {archivo_salida}")
            else:
                print(f"No se encontró contenido relevante o fecha en {url}")
                fallidos.append(url)
        else:
            print(f"Error al acceder a {url}: {response.status_code}")
            fallidos.append(url)
    except Exception as e:
        print(f"Error procesando {url}: {e}")
        fallidos.append(url)
# Out:
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-27_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-pension-mujeres-bienestar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-25_version-estenografica-entrega-de-tarjetas-pension-mujeres-bienestar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-388896?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-25_version-estenografica-programas-para-el-bienestar-388896.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-carretera-mitla-tehuantepec?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-24_version-estenografica-inauguracion-de-la-carretera-mitla-tehuantepec.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-24-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-24_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-24-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-23_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-22_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-21_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-20_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-199-aniversario-de-la-consolidacion-de-la-independencia-en-el-mar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-23_version-estenografica-199-aniversario-de-la-consolidacion-de-la-independencia-en-el-mar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-22_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-21_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-114-aniversario-de-la-revolucion-mexicana?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-20_version-estenografica-114-aniversario-de-la-revolucion-mexicana.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-20_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-primera-sesion-de-trabajo-lucha-contra-el-hambre-y-la-pobreza-en-la-cumbre-del-g20?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-18_version-estenografica-primera-sesion-de-trabajo-lucha-contra-el-hambre-y-la-pobreza-en-la-cumbre-del-g20.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-segunda-sesion-de-trabajo-reforma-de-las-instituciones-de-gobernanza-global-en-la-cumbre-del-g20?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-18_version-estenografica-segunda-sesion-de-trabajo-reforma-de-las-instituciones-de-gobernanza-global-en-la-cumbre-del-g20.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-15_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-14_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-original-encuentro-de-arte-textil-mexicano-en-palacio-nacional?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-13_version-estenografica-original-encuentro-de-arte-textil-mexicano-en-palacio-nacional.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-13_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-12-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-12_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-12-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-11_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-encuentro-con-el-pueblo-de-zacatecas?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-10_version-estenografica-encuentro-con-el-pueblo-de-zacatecas.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-unidad-de-medicina-familiar-no-58?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-10_version-estenografica-inauguracion-de-la-unidad-de-medicina-familiar-no-58.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programa-de-apoyo-al-campo?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-10_version-estenografica-programa-de-apoyo-al-campo.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-camino-artesanal-pata-de-gallo-santiago-teneraca-primera-etapa-en-mezquital-durango?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-09_version-estenografica-inauguracion-camino-artesanal-pata-de-gallo-santiago-teneraca-primera-etapa-en-mezquital-durango.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-08_version-estenografica-pension-mujeres-bienestar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-08_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-07_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-06_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-5-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-05_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-5-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-04_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-31-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-31_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-31-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-30-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-30_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-30-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-29-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-29_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-29-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-28_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-informe-general-de-las-acciones-por-el-huracan-john-en-acapulco-guerrero?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-27_version-estenografica-informe-general-de-las-acciones-por-el-huracan-john-en-acapulco-guerrero.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-en-playas-de-rosarito-baja-california?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-26_version-estenografica-programas-para-el-bienestar-en-playas-de-rosarito-baja-california.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-hospital-general-santa-rosalia?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-25_version-estenografica-inauguracion-del-hospital-general-santa-rosalia.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-25-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-25_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-25-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-24-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-24_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-24-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-23_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-22_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-22-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-21_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-21-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar-y-convenio-pension-universal-para-personas-con-discapacidad-en-yucatan?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-20_version-estenografica-pension-mujeres-bienestar-y-convenio-pension-universal-para-personas-con-discapacidad-en-yucatan.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-en-escarcega-campeche?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-19_version-estenografica-programas-para-el-bienestar-en-escarcega-campeche.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar-y-convenio-pension-universal-para-personas-con-discapacidad?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-18_version-estenografica-pension-mujeres-bienestar-y-convenio-pension-universal-para-personas-con-discapacidad.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-18-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-18_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-18-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-17_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-16_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-resultados-de-la-cumbre-dialogo-ceo-mexico-estados-unidos?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-15_version-estenografica-resultados-de-la-cumbre-dialogo-ceo-mexico-estados-unidos.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-15_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-14_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inicio-de-trabajos-preliminares-para-la-construccion-del-tren-mexico-queretaro?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-13_version-estenografica-inicio-de-trabajos-preliminares-para-la-construccion-del-tren-mexico-queretaro.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-apoyo-bimestral-para-mujeres-de-60-a-64-anos?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-12_version-estenografica-apoyo-bimestral-para-mujeres-de-60-a-64-anos.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-11_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-ceremonia-conmemorativa-de-los-200-anos-de-la-republica?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-10_version-estenografica-ceremonia-conmemorativa-de-los-200-anos-de-la-republica.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-10_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-09_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-08_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-07_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inicio-de-trabajos-preliminares-tren-mexico-pachuca?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-06_version-estenografica-inicio-de-trabajos-preliminares-tren-mexico-pachuca.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-en-morelos?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-05_version-estenografica-programas-para-el-bienestar-en-morelos.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-200-anos-de-la-promulgacion-de-la-constitucion-federal-de-1824-y-creacion-de-la-armada-de-mexico-379875?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-04_version-estenografica-200-anos-de-la-promulgacion-de-la-constitucion-federal-de-1824-y-creacion-de-la-armada-de-mexico-379875.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-04_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-salutacion-de-las-fuerzas-armadas-y-guardia-nacional-a-la-presidenta-constitucional-de-los-estados-unidos-mexicanos?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-03_version-estenografica-salutacion-de-las-fuerzas-armadas-y-guardia-nacional-a-la-presidenta-constitucional-de-los-estados-unidos-mexicanos.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-03_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-la-presidenta-claudia-sheinbaum-pardo-del-2-de-octubre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-02_version-estenografica-conferencia-de-prensa-la-presidenta-claudia-sheinbaum-pardo-del-2-de-octubre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-toma-de-protesta-ante-el-pueblo-de-mexico?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-01_version-estenografica-toma-de-protesta-ante-el-pueblo-de-mexico.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-mensaje-de-la-presidenta-de-los-estados-unidos-mexicanos-claudia-sheinbaum-pardo?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-01_version-estenografica-mensaje-de-la-presidenta-de-los-estados-unidos-mexicanos-claudia-sheinbaum-pardo.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-toma-de-protesta-de-claudia-sheinbaum-como-presidenta-constitucional-de-los-estados-unidos-mexicanos?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-10-01_version-estenografica-toma-de-protesta-de-claudia-sheinbaum-como-presidenta-constitucional-de-los-estados-unidos-mexicanos.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-para-el-bienestar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-19_version-estenografica-entrega-de-tarjetas-de-las-pensiones-para-el-bienestar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-recorrido-por-el-centro-de-rehabilitacion-e-inclusion-teleton-crit-de-tlapa-de-comonfort-guerrero?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-18_version-estenografica-recorrido-por-el-centro-de-rehabilitacion-e-inclusion-teleton-crit-de-tlapa-de-comonfort-guerrero.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-arranque-del-programa-nacional-de-fertilizantes-para-el-bienestar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-18_version-estenografica-arranque-del-programa-nacional-de-fertilizantes-para-el-bienestar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-la-pension-mujeres-bienestar-388297?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-17_version-estenografica-entrega-de-tarjetas-de-la-pension-mujeres-bienestar-388297.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-jovenes-construyendo-el-futuro?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-17_version-estenografica-entrega-de-tarjetas-jovenes-construyendo-el-futuro.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-17_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-centro-integral-para-el-programa-acapulco-se-transforma-contigo?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-16_version-estenografica-centro-integral-para-el-programa-acapulco-se-transforma-contigo.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-encuentro-nacional-municipal?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-16_version-estenografica-encuentro-nacional-municipal.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-16_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-15_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-15-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-14_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-14-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-presentacion-del-plan-mexico-en-el-museo-nacional-de-antropologia?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-13_version-estenografica-presentacion-del-plan-mexico-en-el-museo-nacional-de-antropologia.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-13_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-informe-100-dias-de-gobierno?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-12_version-estenografica-informe-100-dias-de-gobierno.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-si-al-desarme-si-a-la-paz-en-la-basilica-de-guadalupe?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-10_version-estenografica-si-al-desarme-si-a-la-paz-en-la-basilica-de-guadalupe.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-10_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-enero-de-2025-387640?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-09_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-enero-de-2025-387640.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-08_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-8-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-07_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-7-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-reapertura-del-segundo-piso-del-museo-nacional-de-antropologia-grandeza-y-diversidad-cultural-de-mexico?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-06_version-estenografica-reapertura-del-segundo-piso-del-museo-nacional-de-antropologia-grandeza-y-diversidad-cultural-de-mexico.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-06_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-bienestar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-05_version-estenografica-entrega-de-tarjetas-de-las-pensiones-bienestar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-del-bienestar-387268?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-04_version-estenografica-entrega-de-tarjetas-de-las-pensiones-del-bienestar-387268.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-la-pension-mujeres-bienestar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-04_version-estenografica-entrega-de-tarjetas-de-la-pension-mujeres-bienestar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-de-las-pensiones-del-bienestar?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-03_version-estenografica-entrega-de-tarjetas-de-las-pensiones-del-bienestar.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-tarjetas-pension-mujeres-bienestar-zinacantepec-estado-de-mexico?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-03_version-estenografica-entrega-de-tarjetas-pension-mujeres-bienestar-zinacantepec-estado-de-mexico.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-03_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-2-de-enero-de-2025?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2025-01-02_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-2-de-enero-de-2025.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-30-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-30_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-30-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-386975?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-29_version-estenografica-programas-para-el-bienestar-386975.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-autopista-jala-puerto-vallarta?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-28_version-estenografica-inauguracion-de-la-autopista-jala-puerto-vallarta.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-27_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-26_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-23_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-23-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-386732?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-22_version-estenografica-programas-para-el-bienestar-386732.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-la-universidad-del-pueblo-yaqui?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-21_version-estenografica-entrega-de-la-universidad-del-pueblo-yaqui.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-hospital-general-regional-no-02?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-21_version-estenografica-inauguracion-del-hospital-general-regional-no-02.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-restitucion-de-tierras-a-la-comunidad-raramuri-y-plan-de-justicia-para-pueblos-de-la-sierra-tarahumara?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-20_version-estenografica-restitucion-de-tierras-a-la-comunidad-raramuri-y-plan-de-justicia-para-pueblos-de-la-sierra-tarahumara.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-20_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-20-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-19-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-19_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-19-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-18-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-18_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-18-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-17_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-17-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-16_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-16-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-1-aniversario-del-tren-maya-e-inauguracion-de-los-tramos-6-y-7?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-15_version-estenografica-1-aniversario-del-tren-maya-e-inauguracion-de-los-tramos-6-y-7.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inicio-de-la-construccion-del-parque-ecoturistico-la-ceiba?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-14_version-estenografica-inicio-de-la-construccion-del-parque-ecoturistico-la-ceiba.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-entrega-de-titulos-profesionales-a-egresados-de-universidades-benito-juarez?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-13_version-estenografica-entrega-de-titulos-profesionales-a-egresados-de-universidades-benito-juarez.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-115-asamblea-general-ordinaria-del-imss?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-13_version-estenografica-115-asamblea-general-ordinaria-del-imss.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-13_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-13-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-construccion-del-cecyt-20-natalia-serdan-y-upii-alejo-peralta?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-11_version-estenografica-inauguracion-de-la-construccion-del-cecyt-20-natalia-serdan-y-upii-alejo-peralta.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-11_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-11-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-consejo-nacional-de-seguridad-publica?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-10_version-estenografica-consejo-nacional-de-seguridad-publica.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-10_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-10-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-09_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-9-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-programas-para-el-bienestar-385510?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-08_version-estenografica-programas-para-el-bienestar-385510.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-centro-de-salud-docente-con-servicios-ampliados-de-santiago-astata-oaxaca?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-07_version-estenografica-inauguracion-del-centro-de-salud-docente-con-servicios-ampliados-de-santiago-astata-oaxaca.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-autopista-tuxtla-san-cristobal?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-06_version-estenografica-inauguracion-de-la-autopista-tuxtla-san-cristobal.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-06_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-6-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-5-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-05_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-5-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-04_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-4-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-03_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-3-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-firma-de-convenio-entre-el-gobierno-de-mexico-y-la-fundacion-teleton-a-c?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-02_version-estenografica-firma-de-convenio-entre-el-gobierno-de-mexico-y-la-fundacion-teleton-a-c.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-2-de-diciembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-12-02_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-2-de-diciembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-del-hospital-imss-bienestar-de-salud-mental-dr-victor-m-concha-vasquez?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-30_version-estenografica-inauguracion-del-hospital-imss-bienestar-de-salud-mental-dr-victor-m-concha-vasquez.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-inauguracion-de-la-unidad-de-medicina-familiar-no-73?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-30_version-estenografica-inauguracion-de-la-unidad-de-medicina-familiar-no-73.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-29-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-29_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-29-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-28-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-28_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-28-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-premio-nacional-de-deportes-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-27_version-estenografica-premio-nacional-de-deportes-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-27_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-27-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-26_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-26-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-acuerdo-nacional-por-el-derecho-humano-al-agua-y-la-sustentabilidad?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-25_version-estenografica-acuerdo-nacional-por-el-derecho-humano-al-agua-y-la-sustentabilidad.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-25-de-noviembre-de-2024?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-25_version-estenografica-conferencia-de-prensa-de-la-presidenta-claudia-sheinbaum-pardo-del-25-de-noviembre-de-2024.txt
# Procesando: https://www.gob.mx/presidencia/es/articulos/version-estenografica-pension-mujeres-bienestar-en-alvaro-obregon-michoacan?idiom=es
# Archivo guardado: versiones_estenograficas_sheinbaum_2\2024-11-24_version-estenografica-pension-mujeres-bienestar-en-alvaro-obregon-michoacan.txt
# CPU times: total: 2.22 s
# Wall time: 1min 20s

# %%
if fallidos:
    print(f"\nNúmero de conferencias que no se pudieron descargar: {len(fallidos)}")
    print("URLs de las conferencias fallidas:")
    for fallido in fallidos:
        print(fallido)
else:
    print("Todas las conferencias se procesaron correctamente.")
# Out:
# Todas las conferencias se procesaron correctamente.

# %% [markdown]
# ### Preproceso de la data
#
# Cambiaremos el nombre a los archivos ue tienen mismas fechas y los guardamos en un dataframe de polars.

# %%
# Extraer fechas amlo
def extract_date_from_filename(filename):
    # Extraer la fecha del nombre del archivo (formato: dd-mm-aa-version-estenografica-...)
    date_str = filename.split("-")[:3]  # Obtener los primeros tres elementos (dd, mm, aa)
    date_str = "-".join(date_str)  # Unirlos en formato dd-mm-aa
    try:
        # Convertir a formato de fecha estándar (yyyy-mm-dd)
        date_obj = datetime.strptime(date_str, "%d-%m-%y")
        return date_obj.strftime("%Y-%m-%d")  # Devolver en formato yyyy-mm-dd
    except ValueError:
        return None  

def get_title(filename):
    return " ".join(filename.split("-")[3:]).replace(".txt", "").capitalize()

# %%
# %%time
folder_path = "versiones_estenograficas_amlo"  

titles = []
contents = []
authors = []
dates = []

for file in os.listdir(folder_path):
    if file.endswith(".txt"):
        file_path = os.path.join(folder_path, file)
        
        # Leer el contenido 
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        date = extract_date_from_filename(file)
        
        titles.append(get_title(file))
        contents.append(content)
        authors.append("AMLO")
        dates.append(date)

df_amlo = pl.DataFrame({
    "Conferencia": titles,
    "Contenido": contents,
    "Autor": authors,
    "Fecha": dates
})
# Out:
# CPU times: total: 156 ms
# Wall time: 601 ms

# %%
print(df_amlo.head())
print(df_amlo.tail())
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────┬────────────┐
# │ Conferencia                     ┆ Contenido                       ┆ Autor ┆ Fecha      │
# │ ---                             ┆ ---                             ┆ ---   ┆ ---        │
# │ str                             ┆ str                             ┆ str   ┆ str        │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════╪════════════╡
# │ Version estenografica programa… ┆ 2020, Año de Leona Vicario, Be… ┆ AMLO  ┆ 2020-02-01 │
# │ Version estenografica programa… ┆ 2020, Año de Leona Vicario, Be… ┆ AMLO  ┆ 2020-02-01 │
# │ Version estenografica de la co… ┆ 2022: Año de Ricardo Flores Ma… ┆ AMLO  ┆ 2022-02-01 │
# │ Version estenografica de la co… ┆ 2023: Año de Francisco Villa, … ┆ AMLO  ┆ 2023-02-01 │
# │ Version estenografica de la co… ┆ 2021: Año de la IndependenciaP… ┆ AMLO  ┆ 2021-03-01 │
# └─────────────────────────────────┴─────────────────────────────────┴───────┴────────────┘
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────┬────────────┐
# │ Conferencia                     ┆ Contenido                       ┆ Autor ┆ Fecha      │
# │ ---                             ┆ ---                             ┆ ---   ┆ ---        │
# │ str                             ┆ str                             ┆ str   ┆ str        │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════╪════════════╡
# │ Version estenografica 110 asam… ┆ 2019, Año del Caudillo del Sur… ┆ AMLO  ┆ 2019-10-31 │
# │ Version estenografica de la co… ┆ 2019, Año del Caudillo del Sur… ┆ AMLO  ┆ 2019-10-31 │
# │ Version estenografica de la co… ┆ 2022: Año de Ricardo Flores Ma… ┆ AMLO  ┆ 2022-10-31 │
# │ Version estenografica de la co… ┆ 2023: Año de Francisco Villa, … ┆ AMLO  ┆ 2023-10-31 │
# │ Version estenografica de la co… ┆ 2020, Año de Leona Vicario, Be… ┆ AMLO  ┆ 2020-12-31 │
# └─────────────────────────────────┴─────────────────────────────────┴───────┴────────────┘

# %%
df_amlo_sorted = df_amlo.sort("Fecha")
print(df_amlo_sorted.head())
print(df_amlo_sorted.tail())
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────┬────────────┐
# │ Conferencia                     ┆ Contenido                       ┆ Autor ┆ Fecha      │
# │ ---                             ┆ ---                             ┆ ---   ┆ ---        │
# │ str                             ┆ str                             ┆ str   ┆ str        │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════╪════════════╡
# │ Version estenografica inaugura… ┆ 2024: Año de Felipe Carrillo P… ┆ AMLO  ┆ null       │
# │ Version estenografica dialogo … ┆ 2019, Año del Caudillo del Sur… ┆ AMLO  ┆ 2009-10-11 │
# │ Version estenografica de la co… ┆ 2019, Año del Caudillo del Sur… ┆ AMLO  ┆ 2016-12-17 │
# │ Version estenografica programa… ┆ 2019, Año del Caudillo del Sur… ┆ AMLO  ┆ 2019-04-13 │
# │ Version estenografica de la co… ┆ Mañana vamos a Pachuca, Hidalg… ┆ AMLO  ┆ 2019-05-07 │
# └─────────────────────────────────┴─────────────────────────────────┴───────┴────────────┘
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────┬────────────┐
# │ Conferencia                     ┆ Contenido                       ┆ Autor ┆ Fecha      │
# │ ---                             ┆ ---                             ┆ ---   ┆ ---        │
# │ str                             ┆ str                             ┆ str   ┆ str        │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════╪════════════╡
# │ Version estenografica entrega … ┆ 2024: Año de Felipe Carrillo P… ┆ AMLO  ┆ 2024-09-27 │
# │ Version estenografica inaugura… ┆ 2024: Año de Felipe de Carrill… ┆ AMLO  ┆ 2024-09-28 │
# │ Version estenografica tren may… ┆ 2024: Año de Felipe Carrillo P… ┆ AMLO  ┆ 2024-09-29 │
# │ Version estenografica de la ul… ┆ 2024: Año de Felipe Carrillo P… ┆ AMLO  ┆ 2024-09-30 │
# │ Version estenografica conferen… ┆ 2020, Año de Leona Vicario, Be… ┆ AMLO  ┆ 2030-03-03 │
# └─────────────────────────────────┴─────────────────────────────────┴───────┴────────────┘

# %% [markdown]
# Obtenemos las conferencias que no tiene fechas validas y las corregimos manualmente.

# %%
df_invalid_dates = df_amlo.filter(
    (pl.col("Fecha").is_null()) | 
    (~pl.col("Fecha").str.slice(0, 4).is_in(["2019", "2020", "2021", "2022", "2023", "2024"])))
print(df_invalid_dates)
# Out:
# shape: (4, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────┬────────────┐
# │ Conferencia                     ┆ Contenido                       ┆ Autor ┆ Fecha      │
# │ ---                             ┆ ---                             ┆ ---   ┆ ---        │
# │ str                             ┆ str                             ┆ str   ┆ str        │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════╪════════════╡
# │ Version estenografica conferen… ┆ 2020, Año de Leona Vicario, Be… ┆ AMLO  ┆ 2030-03-03 │
# │ Version estenografica dialogo … ┆ 2019, Año del Caudillo del Sur… ┆ AMLO  ┆ 2009-10-11 │
# │ Version estenografica de la co… ┆ 2019, Año del Caudillo del Sur… ┆ AMLO  ┆ 2016-12-17 │
# │ Version estenografica inaugura… ┆ 2024: Año de Felipe Carrillo P… ┆ AMLO  ┆ null       │
# └─────────────────────────────────┴─────────────────────────────────┴───────┴────────────┘

# %% [markdown]
# Para el elemento `df_invalid_dates[0, :]` no es incluido en el análisis.
#
# Las fechas de los otros tres elementos se corrigieron manualmente de la siguiente manera:
#
# - null → **28 de junio de 2024**
# - 2009-10-11 → **11 de octubre de 2019**
# - 2016-12-17 → **17 diciembre de 2019**

# %%
df_amlo = df_amlo.with_columns(
    pl.when(pl.col("Fecha").is_null()).then(pl.lit("2024-06-28"))
    .when(pl.col("Fecha") == pl.lit("2009-10-11")).then(pl.lit("2019-10-11"))
    .when(pl.col("Fecha") == pl.lit("2016-12-17")).then(pl.lit("2019-12-17"))
    .otherwise(pl.col("Fecha"))
    .alias("Fecha")
)

# %%
# Eliminar elemento asociado con 2030-03-03
df_amlo = df_amlo.filter(pl.col("Fecha") != "2030-03-03")

# %% [markdown]
# Ordenamos las conferencias por fecha. Si existen fechas repetidas, añadimos una nueva columna llamada 'Repeticion'
# para asignar un número consecutivo a cada ocurrencia de la misma fecha.

# %%
df_amlo = df_amlo.with_columns(pl.struct(["Fecha"]).rank("ordinal").over("Fecha").alias("Repeticion"))
df_amlo = df_amlo.sort("Fecha")

# %%
print(df_amlo.head())
print(df_amlo.tail())
# Out:
# shape: (5, 5)
# ┌───────────────────────────────────┬────────────────────────────┬───────┬────────────┬────────────┐
# │ Conferencia                       ┆ Contenido                  ┆ Autor ┆ Fecha      ┆ Repeticion │
# │ ---                               ┆ ---                        ┆ ---   ┆ ---        ┆ ---        │
# │ str                               ┆ str                        ┆ str   ┆ str        ┆ u32        │
# ╞═══════════════════════════════════╪════════════════════════════╪═══════╪════════════╪════════════╡
# │ Version estenografica programa…   ┆ 2019, Año del Caudillo del ┆ AMLO  ┆ 2019-04-13 ┆ 1          │
# │                                   ┆ Sur…                       ┆       ┆            ┆            │
# │ Version estenografica de la co…   ┆ Mañana vamos a Pachuca,    ┆ AMLO  ┆ 2019-05-07 ┆ 1          │
# │                                   ┆ Hidalg…                    ┆       ┆            ┆            │
# │ Version estenografica de la co…   ┆ 2019, Año del Caudillo del ┆ AMLO  ┆ 2019-05-09 ┆ 1          │
# │                                   ┆ Sur…                       ┆       ┆            ┆            │
# │ Version estenografica de la co…   ┆ 2019, Año del Caudillo del ┆ AMLO  ┆ 2019-05-15 ┆ 1          │
# │                                   ┆ Sur…                       ┆       ┆            ┆            │
# │ Version estenografica de la co…   ┆ 2019, Año del Caudillo del ┆ AMLO  ┆ 2019-05-17 ┆ 1          │
# │                                   ┆ Sur…                       ┆       ┆            ┆            │
# └───────────────────────────────────┴────────────────────────────┴───────┴────────────┴────────────┘
# shape: (5, 5)
# ┌────────────────────────────────┬───────────────────────────────┬───────┬────────────┬────────────┐
# │ Conferencia                    ┆ Contenido                     ┆ Autor ┆ Fecha      ┆ Repeticion │
# │ ---                            ┆ ---                           ┆ ---   ┆ ---        ┆ ---        │
# │ str                            ┆ str                           ┆ str   ┆ str        ┆ u32        │
# ╞════════════════════════════════╪═══════════════════════════════╪═══════╪════════════╪════════════╡
# │ Version estenografica de la    ┆ 2024: Año de Felipe Carrillo  ┆ AMLO  ┆ 2024-09-27 ┆ 1          │
# │ co…                            ┆ P…                            ┆       ┆            ┆            │
# │ Version estenografica entrega  ┆ 2024: Año de Felipe Carrillo  ┆ AMLO  ┆ 2024-09-27 ┆ 2          │
# │ …                              ┆ P…                            ┆       ┆            ┆            │
# │ Version estenografica          ┆ 2024: Año de Felipe de        ┆ AMLO  ┆ 2024-09-28 ┆ 1          │
# │ inaugura…                      ┆ Carrill…                      ┆       ┆            ┆            │
# │ Version estenografica tren     ┆ 2024: Año de Felipe Carrillo  ┆ AMLO  ┆ 2024-09-29 ┆ 1          │
# │ may…                           ┆ P…                            ┆       ┆            ┆            │
# │ Version estenografica de la    ┆ 2024: Año de Felipe Carrillo  ┆ AMLO  ┆ 2024-09-30 ┆ 1          │
# │ ul…                            ┆ P…                            ┆       ┆            ┆            │
# └────────────────────────────────┴───────────────────────────────┴───────┴────────────┴────────────┘

# %%
print(f"Número de conferecnias: {df_amlo.height}")
print(f"Número de columnas: {df_amlo.width}")
print(f"Columnas: {df_amlo.columns}")
print(f"Shape: {df_amlo.shape}")
# Out:
# Número de conferecnias: 1961
# Número de columnas: 5
# Columnas: ['Conferencia', 'Contenido', 'Autor', 'Fecha', 'Repeticion']
# Shape: (1961, 5)

# %% [markdown]
# **Ahora para Sheinbaum**

# %%
def extract_date_from_filename(filename):
    date_str = filename.split("_")[0]  # Obtener la parte antes del primer guión bajo (yyyy-mm-dd)
    try:
        date_obj = datetime.strptime(date_str, "%Y-%m-%d")
        return date_obj.strftime("%Y-%m-%d")  
    except ValueError:
        return None

def get_title(filename):
    return " ".join(filename.split("-")[3:]).replace(".txt", "").capitalize()

# %%
# %%time
folder_path = "versiones_estenograficas_sheinbaum"  
titles = []
contents = []
authors = []
dates = []

for file in os.listdir(folder_path):
    if file.endswith(".txt"):
        file_path = os.path.join(folder_path, file)
        
        # Leer el contenido 
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        date = extract_date_from_filename(file)
        
        titles.append(get_title(file))
        contents.append(content)
        authors.append("Sheinbaum")
        dates.append(date)

df_shein = pl.DataFrame({
    "Conferencia": titles,
    "Contenido": contents,
    "Autor": authors,
    "Fecha": dates
})
# Out:
# CPU times: total: 15.6 ms
# Wall time: 46.9 ms

# %%
df_shein_sorted = df_shein.sort("Fecha")
print(df_shein_sorted.head())
print(df_shein_sorted.tail())
# Out:
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────────┬────────────┐
# │ Conferencia                     ┆ Contenido                       ┆ Autor     ┆ Fecha      │
# │ ---                             ┆ ---                             ┆ ---       ┆ ---        │
# │ str                             ┆ str                             ┆ str       ┆ str        │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════════╪════════════╡
# │ Estenografica mensaje de la pr… ┆ PRESIDENTA CLAUDIA SHEINBAUM P… ┆ Sheinbaum ┆ 2024-10-01 │
# │ Estenografica toma de protesta… ┆ MODERADORA 1: Mexicanas y mexi… ┆ Sheinbaum ┆ 2024-10-01 │
# │ Estenografica toma de protesta… ┆ IFIGENIA MARTÍNEZ Y HERNÁNDEZ,… ┆ Sheinbaum ┆ 2024-10-01 │
# │ Estenografica conferencia de p… ┆ PRESIDENTA CLAUDIA SHEINBAUM P… ┆ Sheinbaum ┆ 2024-10-02 │
# │ Estenografica conferencia de p… ┆ PRESIDENTA CLAUDIA SHEINBAUM P… ┆ Sheinbaum ┆ 2024-10-03 │
# └─────────────────────────────────┴─────────────────────────────────┴───────────┴────────────┘
# shape: (5, 4)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────────┬────────────┐
# │ Conferencia                     ┆ Contenido                       ┆ Autor     ┆ Fecha      │
# │ ---                             ┆ ---                             ┆ ---       ┆ ---        │
# │ str                             ┆ str                             ┆ str       ┆ str        │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════════╪════════════╡
# │ Estenografica conferencia de p… ┆ PRESIDENTA DE MÉXICO, CLAUDIA … ┆ Sheinbaum ┆ 2025-01-24 │
# │ Estenografica inauguracion de … ┆ MODERADOR:Escuchemos el mensaj… ┆ Sheinbaum ┆ 2025-01-24 │
# │ Estenografica entrega de tarje… ┆ MODERADOR:Estimado público, es… ┆ Sheinbaum ┆ 2025-01-25 │
# │ Estenografica programas para e… ┆ MODERADOR:Estimado público, es… ┆ Sheinbaum ┆ 2025-01-25 │
# │ Estenografica conferencia de p… ┆ PRESIDENTA DE MÉXICO, CLAUDIA … ┆ Sheinbaum ┆ 2025-01-27 │
# └─────────────────────────────────┴─────────────────────────────────┴───────────┴────────────┘

# %%
df_shein = df_shein.with_columns(pl.struct(["Fecha"]).rank("ordinal").over("Fecha").alias("Repeticion"))
df_shein = df_shein.sort("Fecha")

# %%
print(df_shein.head(10))
# Out:
# shape: (10, 5)
# ┌──────────────────────────────┬─────────────────────────────┬───────────┬────────────┬────────────┐
# │ Conferencia                  ┆ Contenido                   ┆ Autor     ┆ Fecha      ┆ Repeticion │
# │ ---                          ┆ ---                         ┆ ---       ┆ ---        ┆ ---        │
# │ str                          ┆ str                         ┆ str       ┆ str        ┆ u32        │
# ╞══════════════════════════════╪═════════════════════════════╪═══════════╪════════════╪════════════╡
# │ Estenografica mensaje de la  ┆ PRESIDENTA CLAUDIA          ┆ Sheinbaum ┆ 2024-10-01 ┆ 1          │
# │ pr…                          ┆ SHEINBAUM P…                ┆           ┆            ┆            │
# │ Estenografica toma de        ┆ MODERADORA 1: Mexicanas y   ┆ Sheinbaum ┆ 2024-10-01 ┆ 2          │
# │ protesta…                    ┆ mexi…                       ┆           ┆            ┆            │
# │ Estenografica toma de        ┆ IFIGENIA MARTÍNEZ Y         ┆ Sheinbaum ┆ 2024-10-01 ┆ 3          │
# │ protesta…                    ┆ HERNÁNDEZ,…                 ┆           ┆            ┆            │
# │ Estenografica conferencia de ┆ PRESIDENTA CLAUDIA          ┆ Sheinbaum ┆ 2024-10-02 ┆ 1          │
# │ p…                           ┆ SHEINBAUM P…                ┆           ┆            ┆            │
# │ Estenografica conferencia de ┆ PRESIDENTA CLAUDIA          ┆ Sheinbaum ┆ 2024-10-03 ┆ 1          │
# │ p…                           ┆ SHEINBAUM P…                ┆           ┆            ┆            │
# │ Estenografica salutacion de  ┆ MODERADORA:La presidenta de ┆ Sheinbaum ┆ 2024-10-03 ┆ 2          │
# │ la…                          ┆ la…                         ┆           ┆            ┆            │
# │ Estenografica 200 anos de la ┆ MODERADOR:Damos inicio a la ┆ Sheinbaum ┆ 2024-10-04 ┆ 1          │
# │ p…                           ┆ ce…                         ┆           ┆            ┆            │
# │ Estenografica conferencia de ┆ PRESIDENTA CLAUDIA          ┆ Sheinbaum ┆ 2024-10-04 ┆ 2          │
# │ p…                           ┆ SHEINBAUM P…                ┆           ┆            ┆            │
# │ Estenografica programas para ┆ MODERADOR:Preside este      ┆ Sheinbaum ┆ 2024-10-05 ┆ 1          │
# │ e…                           ┆ evento,…                    ┆           ┆            ┆            │
# │ Estenografica inicio de      ┆ MODERADORA:Damos inicio a   ┆ Sheinbaum ┆ 2024-10-06 ┆ 1          │
# │ trabaj…                      ┆ este…                       ┆           ┆            ┆            │
# └──────────────────────────────┴─────────────────────────────┴───────────┴────────────┴────────────┘

# %%
print(f"Número de conferecnias: {df_shein.height}")
print(f"Número de columnas: {df_shein.width}")
print(f"Columnas: {df_shein.columns}")
print(f"Shape: {df_shein.shape}")
# Out:
# Número de conferecnias: 143
# Número de columnas: 5
# Columnas: ['Conferencia', 'Contenido', 'Autor', 'Fecha', 'Repeticion']
# Shape: (143, 5)

# %% [markdown]
# ### Guardar conferencias

# %%
# Combinamos los dataframes
df_combined = pl.concat([df_shein, df_amlo], how="vertical")

# %%
if not os.path.exists("data"):
    os.makedirs("data")

df.write_parquet("data/transcripts.parquet")
df.write_csv("data/transcripts.csv")

# %%
# %%time
if not os.path.exists("data"):
    os.makedirs("data")

df_combined.write_parquet("data/transcripts.parquet")
df_combined.write_csv("data/transcripts.csv")
# Out:
# CPU times: total: 531 ms
# Wall time: 696 ms
